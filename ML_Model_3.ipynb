# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\Hp\Downloads\archive (15)\BankChurners.csv")

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
df['Income_Category'].value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Category, dtype: int64

# %%
df['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %%
df['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
df['Marital_Status'].value_counts()
# Out:
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64

# %%
df['Card_Category'].value_counts()
# Out:
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
df1=df.drop(df.columns[[21,22]],axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
ic=df['Income_Category'].unique()
ic
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
df1.Income_Category=df1.Income_Category.replace('Unknown',0)
df1.Income_Category=df1.Income_Category.replace('Less than $40K',1)
df1.Income_Category=df1.Income_Category.replace('$40K - $60K',2)
df1.Income_Category=df1.Income_Category.replace('$60K - $80K',3)
df1.Income_Category=df1.Income_Category.replace('$80K - $120K',4)
df1.Income_Category=df1.Income_Category.replace('$120K +',5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  int64
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
df1.Gender=df1.Gender.replace('F',0)
df1.Gender=df1.Gender.replace('M',1)
df1.Education_Level=df1.Education_Level.replace('Unknown',0)
df1.Education_Level=df1.Education_Level.replace('Uneducated',1)
df1.Education_Level=df1.Education_Level.replace('High School',2)
df1.Education_Level=df1.Education_Level.replace('College',3)
df1.Education_Level=df1.Education_Level.replace('Graduate',4)
df1.Education_Level=df1.Education_Level.replace('Post-Graduate',5)
df1.Education_Level=df1.Education_Level.replace('Doctorate',6)
df1.Marital_Status=df1.Marital_Status.replace('Unknown',0)
df1.Marital_Status=df1.Marital_Status.replace('Divorced',1)
df1.Marital_Status=df1.Marital_Status.replace('Single',2)
df1.Marital_Status=df1.Marital_Status.replace('Married',3)
df1.Card_Category=df1.Card_Category.replace('Blue',0)
df1.Card_Category=df1.Card_Category.replace('Silver',1)
df1.Card_Category=df1.Card_Category.replace('Gold',2)
df1.Card_Category=df1.Card_Category.replace('Platinum',3)

# %%
df1.Attrition_Flag=df1.Attrition_Flag.replace('Existing Customer',0)
df1.Attrition_Flag=df1.Attrition_Flag.replace('Attrited Customer',1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  int64
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  int64
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  int64
#  6   Marital_Status            10127 non-null  int64
#  7   Income_Category           10127 non-null  int64
#  8   Card_Category             10127 non-null  int64
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
#  13  Credit_Limit              10127 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df2=df1.drop(['CLIENTNUM'],axis=1)

# %%
plt.subplots(figsize=(20,20))

dataplot = sns.heatmap(df2.corr(), cmap="YlGnBu", annot=True) 

plt.show()

# %%
df1
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383               0            45       1                3
# 1      818770008               0            49       0                5
# 2      713982108               0            51       1                3
# 3      769911858               0            40       0                4
# 4      709106358               0            40       1                3
# ...          ...             ...           ...     ...              ...
# 10122  772366833               0            50       1                2
# 10123  710638233               1            41       1                2
# 10124  716506083               1            44       0                1
# 10125  717406983               1            30       1                2
# 10126  714337233               1            43       0                2
#
#        Education_Level  Marital_Status  Income_Category  Card_Category  \
# ...

# %%
df3=df2.drop(['Attrition_Flag'],axis=1)

# %%
target=df2.Attrition_Flag
target
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10122    0
# 10123    1
# 10124    1
# 10125    1
# 10126    1
# Name: Attrition_Flag, Length: 10127, dtype: int64

# %%
plt.subplots(figsize=(20,20))

dataplot = sns.heatmap(df3.corr(), cmap="YlGnBu", annot=True) 

plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
X_train,X_test,y_train,y_test=train_test_split(df3,target,test_size=0.2,random_state=30)

# %%
len(X_train)
# Out:
# 8101

# %%
len(y_test)
# Out:
# 2026

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
model=GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_Age              10127 non-null  int64
#  1   Gender                    10127 non-null  int64
#  2   Dependent_count           10127 non-null  int64
#  3   Education_Level           10127 non-null  int64
#  4   Marital_Status            10127 non-null  int64
#  5   Income_Category           10127 non-null  int64
#  6   Card_Category             10127 non-null  int64
#  7   Months_on_book            10127 non-null  int64
#  8   Total_Relationship_Count  10127 non-null  int64
#  9   Months_Inactive_12_mon    10127 non-null  int64
#  10  Contacts_Count_12_mon     10127 non-null  int64
#  11  Credit_Limit              10127 non-null  float64
#  12  Total_Revolving_Bal       10127 non-null  int64
#  13  Avg_Open_To_Buy           10127 non-null  float64
# ...

# %%
len(X_test)
# Out:
# 2026

# %%
model.score(X_test,y_test)
# Out:
# 0.9027640671273445

# %%
import numpy as np

# %%
np.logspace(0,-9, num=10)
# Out:
# array([1.e+00, 1.e-01, 1.e-02, 1.e-03, 1.e-04, 1.e-05, 1.e-06, 1.e-07,
#        1.e-08, 1.e-09])

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                    n_repeats=3, 
                                    random_state=999)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.preprocessing import PowerTransformer
params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=model, 
                     param_grid=params_NB, 
                     cv=cv_method,
                     verbose=1, 
                     scoring='accuracy')

Data_transformed = PowerTransformer().fit_transform(X_test)

gs_NB.fit(Data_transformed, y_test)
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=999),
#              estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy', verbose=1)

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 0.43287612810830584}

# %%
gs_NB.best_score_
# Out:
# 0.8897666686938716

# %%
results_NB = pd.DataFrame(gs_NB.cv_results_['params'])
results_NB['test_score'] = gs_NB.cv_results_['mean_test_score']

# %%
plt.plot(results_NB['var_smoothing'], results_NB['test_score'], marker = '.')    
plt.xlabel('Var. Smoothing')
plt.ylabel("Mean CV Score")
plt.title("NB Performance Comparison")
plt.show()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
predict_test = gs_NB.predict(Data_transformed)

accuracy_test = accuracy_score(y_test,predict_test)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on test dataset :  0.8914116485686081

# %%
sns.heatmap((confusion_matrix(y_test,predict_test)),annot=True,fmt='.5g',cmap="YlGn").set_title('Test Data')
# Out:
# Text(0.5, 1.0, 'Test Data')
